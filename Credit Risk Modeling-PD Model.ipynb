# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading Data

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv',index_col =0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv',index_col =0)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv',index_col =0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv',index_col =0,header=None)
# Out:
# /var/folders/hg/jgrbrly50wz_1z4gjyycxhzr0000gn/T/ipykernel_72973/40061464.py:1: DtypeWarning: Columns (27,29,32,33,36,58,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv',index_col =0)
# /var/folders/hg/jgrbrly50wz_1z4gjyycxhzr0000gn/T/ipykernel_72973/40061464.py:3: DtypeWarning: Columns (27,29,32,33,36,58,77) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv',index_col =0)

# %%
loan_data_targets_train.head()
# Out:
#         good_bad
# 427211         1
# 206088         1
# 136020         1
# 412305         0
# 36159          0

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 323)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (373028, 323)

# %%
loan_data_targets_test.shape
# Out:
# (93258, 1)

# %% [markdown]
# # Selecting Features

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 104 columns]

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows = None

# %%
reg.fit(inputs_train,loan_data_targets_train)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([0.95297018])

# %%
reg.coef_
# Out:
# array([[ 0.98798379,  0.76575123,  0.57742491,  0.41240499,  0.27612181,
#          0.09958675,  0.08961168,  0.11018187,  0.02103328,  0.04709138,
#          0.05514819,  0.05336204,  0.06528008,  0.12663789,  0.08534806,
#          0.18027743,  0.22302287,  0.2162433 ,  0.25239418,  0.31013063,
#          0.51241284,  0.1051565 , -0.00654657,  0.30740733,  0.20252121,
#          0.22538108,  0.2676009 ,  0.05621797,  0.08685163, -0.02972941,
#          0.07230248,  0.03947564,  0.01155872,  0.07626457,  0.76083507,
#          0.55628824,  0.45000364,  0.25596039,  0.10158758, -0.13846043,
#         -0.29004032,  0.95117714,  0.61232537,  0.3730401 ,  0.15784534,
#          0.04499615,  0.02327625,  0.06706   ,  0.10864673,  0.11068974,
#          0.10027317,  0.05038003, -0.92027597, -1.06470988, -1.19970566,
#          0.31383694,  0.19447198,  0.16648316,  0.16044892,  0.13977532,
#          0.17427435,  0.10427498,  0.11061046,  0.15732942, -0.02114581,
#          0.02775394,  0.19870334,  0.10823774,  0.0788247 ,  0.09452637,
#          0.10993515,  0.12515166,  0.1498786 ,  0.29562937, -0.06832034,
#         -0.00183355,  0.09618639,  0.16214347,  0.23865624,  0.30824816,
#          0.38508222,  0.40294536,  0.47889492,  0.56557645,  0.50840289,
#          0.26232814,  0.40531758,  0.43044525,  0.37153684,  0.29741268,
#          0.20081423,  0.18332121,  0.15773691,  0.11417329,  0.02361827,
#          0.10482955,  0.10844084,  0.06492472, -0.39326596, -0.28207679,
#         -0.35246405, -0.19927626, -0.38149409, -0.46481556]])

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept      0.952970
# 1                                grade:A      0.987984
# 2                                grade:B      0.765751
# 3                                grade:C      0.577425
# 4                                grade:D      0.412405
# 5                                grade:E      0.276122
# 6                                grade:F      0.099587
# 7                     home_ownership:OWN      0.089612
# 8                home_ownership:MORTGAGE      0.110182
# 9                       addr_state:NM_VA      0.021033
# 10                         addr_state:NY      0.047091
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.055148
# 12                         addr_state:CA      0.053362
# 13                addr_state:UT_KY_AZ_NJ      0.065280
# 14             addr_state:AR_MI_PA_OH_MN      0.126638
# 15             addr_state:RI_MA_DE_SD_IN      0.085348
# 16                   addr_state:GA_WA_OR      0.180277
# 17                      addr_state:WI_MT      0.223023
# 18                         addr_state:TX      0.216243
# 19                      addr_state:IL_CT      0.252394
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.310131
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.512413
# 22      verification_status:Not Verified      0.105157
# 23   verification_status:Source Verified     -0.006547
# 24                   purpose:credit_card      0.307407
# 25            purpose:debt_consolidation      0.202521
# 26            purpose:oth__med__vacation      0.225381
# 27   purpose:major_purch__car__home_impr      0.267601
# 28                 initial_list_status:w      0.056218
# 29                               term:36      0.086852
# 30                          emp_length:1     -0.029729
# 31                        emp_length:2-4      0.072302
# 32                        emp_length:5-6      0.039476
# 33                        emp_length:7-9      0.011559
# 34                         emp_length:10      0.076265
# 35                mths_since_issue_d:<38      0.760835
# 36              mths_since_issue_d:38-39      0.556288
# 37              mths_since_issue_d:40-41      0.450004
# 38              mths_since_issue_d:42-48      0.255960
# 39              mths_since_issue_d:49-52      0.101588
# 40              mths_since_issue_d:53-64     -0.138460
# 41              mths_since_issue_d:65-84     -0.290040
# 42                       int_rate:<9.548      0.951177
# 43                 int_rate:9.548-12.025      0.612325
# 44                 int_rate:12.025-15.74      0.373040
# 45                 int_rate:15.74-20.281      0.157845
# 46   mths_since_earliest_cr_line:141-164      0.044996
# 47   mths_since_earliest_cr_line:165-247      0.023276
# 48   mths_since_earliest_cr_line:248-270      0.067060
# 49   mths_since_earliest_cr_line:271-352      0.108647
# 50      mths_since_earliest_cr_line:>352      0.110690
# 51                         delinq_2yrs:0      0.100273
# 52                       delinq_2yrs:1-3      0.050380
# 53                      inq_last_6mths:0     -0.920276
# 54                    inq_last_6mths:1-2     -1.064710
# 55                    inq_last_6mths:3-6     -1.199706
# 56                          open_acc:1-3      0.313837
# 57                         open_acc:4-12      0.194472
# 58                        open_acc:13-17      0.166483
# 59                        open_acc:18-22      0.160449
# 60                        open_acc:23-25      0.139775
# 61                        open_acc:26-30      0.174274
# 62                         open_acc:>=31      0.104275
# 63                           pub_rec:3-4      0.110610
# 64                           pub_rec:>=5      0.157329
# 65                       total_acc:28-51     -0.021146
# 66                        total_acc:>=52      0.027754
# 67                    acc_now_delinq:>=1      0.198703
# 68               total_rev_hi_lim:5K-10K      0.108238
# 69              total_rev_hi_lim:10K-20K      0.078825
# 70              total_rev_hi_lim:20K-30K      0.094526
# 71              total_rev_hi_lim:30K-40K      0.109935
# 72              total_rev_hi_lim:40K-55K      0.125152
# 73              total_rev_hi_lim:55K-95K      0.149879
# 74                 total_rev_hi_lim:>95K      0.295629
# 75                    annual_inc:20K-30K     -0.068320
# 76                    annual_inc:30K-40K     -0.001834
# 77                    annual_inc:40K-50K      0.096186
# 78                    annual_inc:50K-60K      0.162143
# 79                    annual_inc:60K-70K      0.238656
# 80                    annual_inc:70K-80K      0.308248
# 81                    annual_inc:80K-90K      0.385082
# 82                   annual_inc:90K-100K      0.402945
# 83                  annual_inc:100K-120K      0.478895
# 84                  annual_inc:120K-140K      0.565576
# 85                      annual_inc:>140K      0.508403
# 86                             dti:<=1.4      0.262328
# 87                           dti:1.4-3.5      0.405318
# 88                           dti:3.5-7.7      0.430445
# 89                          dti:7.7-10.5      0.371537
# 90                         dti:10.5-16.1      0.297413
# 91                         dti:16.1-20.3      0.200814
# 92                         dti:20.3-21.7      0.183321
# 93                         dti:21.7-22.4      0.157737
# 94                           dti:22.4-35      0.114173
# 95        mths_since_last_delinq:Missing      0.023618
# 96           mths_since_last_delinq:4-30      0.104830
# 97          mths_since_last_delinq:31-56      0.108441
# 98           mths_since_last_delinq:>=57      0.064925
# 99        mths_since_last_record:Missing     -0.393266
# 100          mths_since_last_record:3-20     -0.282077
# 101         mths_since_last_record:21-31     -0.352464
# 102         mths_since_last_record:32-80     -0.199276
# 103         mths_since_last_record:81-86     -0.381494
# 104          mths_since_last_record:>=86     -0.464816

# %% [markdown]
# # Logistic Regression Model with P-Values

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                             Feature name  Coefficients
# 0                              Intercept      0.952970
# 1                                grade:A      0.987984
# 2                                grade:B      0.765751
# 3                                grade:C      0.577425
# 4                                grade:D      0.412405
# 5                                grade:E      0.276122
# 6                                grade:F      0.099587
# 7                     home_ownership:OWN      0.089612
# 8                home_ownership:MORTGAGE      0.110182
# 9                       addr_state:NM_VA      0.021033
# 10                         addr_state:NY      0.047091
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.055148
# 12                         addr_state:CA      0.053362
# 13                addr_state:UT_KY_AZ_NJ      0.065280
# 14             addr_state:AR_MI_PA_OH_MN      0.126638
# 15             addr_state:RI_MA_DE_SD_IN      0.085348
# 16                   addr_state:GA_WA_OR      0.180277
# 17                      addr_state:WI_MT      0.223023
# 18                         addr_state:TX      0.216243
# 19                      addr_state:IL_CT      0.252394
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.310131
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.512413
# 22      verification_status:Not Verified      0.105157
# 23   verification_status:Source Verified     -0.006547
# 24                   purpose:credit_card      0.307407
# 25            purpose:debt_consolidation      0.202521
# 26            purpose:oth__med__vacation      0.225381
# 27   purpose:major_purch__car__home_impr      0.267601
# 28                 initial_list_status:w      0.056218
# 29                               term:36      0.086852
# 30                          emp_length:1     -0.029729
# 31                        emp_length:2-4      0.072302
# 32                        emp_length:5-6      0.039476
# 33                        emp_length:7-9      0.011559
# 34                         emp_length:10      0.076265
# 35                mths_since_issue_d:<38      0.760835
# 36              mths_since_issue_d:38-39      0.556288
# 37              mths_since_issue_d:40-41      0.450004
# 38              mths_since_issue_d:42-48      0.255960
# 39              mths_since_issue_d:49-52      0.101588
# 40              mths_since_issue_d:53-64     -0.138460
# 41              mths_since_issue_d:65-84     -0.290040
# 42                       int_rate:<9.548      0.951177
# 43                 int_rate:9.548-12.025      0.612325
# 44                 int_rate:12.025-15.74      0.373040
# 45                 int_rate:15.74-20.281      0.157845
# 46   mths_since_earliest_cr_line:141-164      0.044996
# 47   mths_since_earliest_cr_line:165-247      0.023276
# 48   mths_since_earliest_cr_line:248-270      0.067060
# 49   mths_since_earliest_cr_line:271-352      0.108647
# 50      mths_since_earliest_cr_line:>352      0.110690
# 51                         delinq_2yrs:0      0.100273
# 52                       delinq_2yrs:1-3      0.050380
# 53                      inq_last_6mths:0     -0.920276
# 54                    inq_last_6mths:1-2     -1.064710
# 55                    inq_last_6mths:3-6     -1.199706
# 56                          open_acc:1-3      0.313837
# 57                         open_acc:4-12      0.194472
# 58                        open_acc:13-17      0.166483
# 59                        open_acc:18-22      0.160449
# 60                        open_acc:23-25      0.139775
# 61                        open_acc:26-30      0.174274
# 62                         open_acc:>=31      0.104275
# 63                           pub_rec:3-4      0.110610
# 64                           pub_rec:>=5      0.157329
# 65                       total_acc:28-51     -0.021146
# 66                        total_acc:>=52      0.027754
# 67                    acc_now_delinq:>=1      0.198703
# 68               total_rev_hi_lim:5K-10K      0.108238
# 69              total_rev_hi_lim:10K-20K      0.078825
# 70              total_rev_hi_lim:20K-30K      0.094526
# 71              total_rev_hi_lim:30K-40K      0.109935
# 72              total_rev_hi_lim:40K-55K      0.125152
# 73              total_rev_hi_lim:55K-95K      0.149879
# 74                 total_rev_hi_lim:>95K      0.295629
# 75                    annual_inc:20K-30K     -0.068320
# 76                    annual_inc:30K-40K     -0.001834
# 77                    annual_inc:40K-50K      0.096186
# 78                    annual_inc:50K-60K      0.162143
# 79                    annual_inc:60K-70K      0.238656
# 80                    annual_inc:70K-80K      0.308248
# 81                    annual_inc:80K-90K      0.385082
# 82                   annual_inc:90K-100K      0.402945
# 83                  annual_inc:100K-120K      0.478895
# 84                  annual_inc:120K-140K      0.565576
# 85                      annual_inc:>140K      0.508403
# 86                             dti:<=1.4      0.262328
# 87                           dti:1.4-3.5      0.405318
# 88                           dti:3.5-7.7      0.430445
# 89                          dti:7.7-10.5      0.371537
# 90                         dti:10.5-16.1      0.297413
# 91                         dti:16.1-20.3      0.200814
# 92                         dti:20.3-21.7      0.183321
# 93                         dti:21.7-22.4      0.157737
# 94                           dti:22.4-35      0.114173
# 95        mths_since_last_delinq:Missing      0.023618
# 96           mths_since_last_delinq:4-30      0.104830
# 97          mths_since_last_delinq:31-56      0.108441
# 98           mths_since_last_delinq:>=57      0.064925
# 99        mths_since_last_record:Missing     -0.393266
# 100          mths_since_last_record:3-20     -0.282077
# 101         mths_since_last_record:21-31     -0.352464
# 102         mths_since_last_record:32-80     -0.199276
# 103         mths_since_last_record:81-86     -0.381494
# 104          mths_since_last_record:>=86     -0.464816

# %%
p_values = reg.p_values

# %%
p_values = np.append(np.nan, np.array(p_values))

# %%
summary_table['p_values'] = p_values

# %%
summary_table
# Out:
#                             Feature name  Coefficients      p_values
# 0                              Intercept      0.952970           NaN
# 1                                grade:A      0.987984  1.142278e-26
# 2                                grade:B      0.765751  1.497346e-34
# 3                                grade:C      0.577425  2.649976e-23
# 4                                grade:D      0.412405  8.219883e-14
# 5                                grade:E      0.276122  2.092676e-08
# 6                                grade:F      0.099587  5.208958e-02
# 7                     home_ownership:OWN      0.089612  9.809495e-06
# 8                home_ownership:MORTGAGE      0.110182  6.188347e-18
# 9                       addr_state:NM_VA      0.021033  5.134246e-01
# 10                         addr_state:NY      0.047091  5.393579e-02
# 11          addr_state:OK_TN_MO_LA_MD_NC      0.055148  1.822150e-02
# 12                         addr_state:CA      0.053362  1.255338e-02
# 13                addr_state:UT_KY_AZ_NJ      0.065280  9.304879e-03
# 14             addr_state:AR_MI_PA_OH_MN      0.126638  2.529449e-08
# 15             addr_state:RI_MA_DE_SD_IN      0.085348  4.487164e-03
# 16                   addr_state:GA_WA_OR      0.180277  2.080311e-11
# 17                      addr_state:WI_MT      0.223023  3.087249e-06
# 18                         addr_state:TX      0.216243  1.448855e-16
# 19                      addr_state:IL_CT      0.252394  1.065496e-17
# 20          addr_state:KS_SC_CO_VT_AK_MS      0.310131  1.679563e-23
# 21          addr_state:WV_NH_WY_DC_ME_ID      0.512413  1.157762e-21
# 22      verification_status:Not Verified      0.105157  8.728722e-13
# 23   verification_status:Source Verified     -0.006547  6.274352e-01
# 24                   purpose:credit_card      0.307407  1.499555e-26
# 25            purpose:debt_consolidation      0.202521  2.469492e-14
# 26            purpose:oth__med__vacation      0.225381  1.242426e-12
# 27   purpose:major_purch__car__home_impr      0.267601  4.267963e-17
# 28                 initial_list_status:w      0.056218  1.670862e-05
# 29                               term:36      0.086852  1.066067e-09
# 30                          emp_length:1     -0.029729  2.322080e-01
# 31                        emp_length:2-4      0.072302  1.091784e-03
# 32                        emp_length:5-6      0.039476  1.055739e-01
# 33                        emp_length:7-9      0.011559  6.290514e-01
# 34                         emp_length:10      0.076265  5.435430e-04
# 35                mths_since_issue_d:<38      0.760835  6.937913e-63
# 36              mths_since_issue_d:38-39      0.556288  1.154980e-39
# 37              mths_since_issue_d:40-41      0.450004  2.596071e-27
# 38              mths_since_issue_d:42-48      0.255960  3.456692e-11
# 39              mths_since_issue_d:49-52      0.101588  1.202905e-02
# 40              mths_since_issue_d:53-64     -0.138460  2.994489e-04
# 41              mths_since_issue_d:65-84     -0.290040  7.525983e-22
# 42                       int_rate:<9.548      0.951177  9.702268e-35
# 43                 int_rate:9.548-12.025      0.612325  2.011766e-41
# 44                 int_rate:12.025-15.74      0.373040  3.031413e-23
# 45                 int_rate:15.74-20.281      0.157845  1.075821e-07
# 46   mths_since_earliest_cr_line:141-164      0.044996  7.283061e-02
# 47   mths_since_earliest_cr_line:165-247      0.023276  2.547266e-01
# 48   mths_since_earliest_cr_line:248-270      0.067060  1.210162e-02
# 49   mths_since_earliest_cr_line:271-352      0.108647  5.943223e-06
# 50      mths_since_earliest_cr_line:>352      0.110690  4.562882e-05
# 51                         delinq_2yrs:0      0.100273  7.934849e-02
# 52                       delinq_2yrs:1-3      0.050380  3.474503e-01
# 53                      inq_last_6mths:0     -0.920276  6.494572e-06
# 54                    inq_last_6mths:1-2     -1.064710  1.790904e-07
# 55                    inq_last_6mths:3-6     -1.199706  4.296089e-09
# 56                          open_acc:1-3      0.313837  1.949637e-01
# 57                         open_acc:4-12      0.194472  4.160592e-01
# 58                        open_acc:13-17      0.166483  4.866321e-01
# 59                        open_acc:18-22      0.160449  5.037426e-01
# 60                        open_acc:23-25      0.139775  5.653971e-01
# 61                        open_acc:26-30      0.174274  4.801668e-01
# 62                         open_acc:>=31      0.104275  6.850834e-01
# 63                           pub_rec:3-4      0.110610  2.433988e-01
# 64                           pub_rec:>=5      0.157329  4.137377e-01
# 65                       total_acc:28-51     -0.021146  1.382332e-01
# 66                        total_acc:>=52      0.027754  4.883631e-01
# 67                    acc_now_delinq:>=1      0.198703  6.419713e-02
# 68               total_rev_hi_lim:5K-10K      0.108238  3.953617e-04
# 69              total_rev_hi_lim:10K-20K      0.078825  4.661085e-03
# 70              total_rev_hi_lim:20K-30K      0.094526  1.221717e-03
# 71              total_rev_hi_lim:30K-40K      0.109935  5.316738e-04
# 72              total_rev_hi_lim:40K-55K      0.125152  2.035391e-04
# 73              total_rev_hi_lim:55K-95K      0.149879  5.855435e-05
# 74                 total_rev_hi_lim:>95K      0.295629  2.470001e-07
# 75                    annual_inc:20K-30K     -0.068320  1.166672e-01
# 76                    annual_inc:30K-40K     -0.001834  9.651221e-01
# 77                    annual_inc:40K-50K      0.096186  2.181903e-02
# 78                    annual_inc:50K-60K      0.162143  1.356538e-04
# 79                    annual_inc:60K-70K      0.238656  4.053616e-08
# 80                    annual_inc:70K-80K      0.308248  3.666916e-12
# 81                    annual_inc:80K-90K      0.385082  7.255231e-17
# 82                   annual_inc:90K-100K      0.402945  3.242267e-17
# 83                  annual_inc:100K-120K      0.478895  5.974207e-24
# 84                  annual_inc:120K-140K      0.565576  5.536201e-26
# 85                      annual_inc:>140K      0.508403  2.343876e-24
# 86                             dti:<=1.4      0.262328  3.170601e-03
# 87                           dti:1.4-3.5      0.405318  4.927121e-08
# 88                           dti:3.5-7.7      0.430445  2.124333e-11
# 89                          dti:7.7-10.5      0.371537  5.402548e-09
# 90                         dti:10.5-16.1      0.297413  1.384431e-06
# 91                         dti:16.1-20.3      0.200814  1.109840e-03
# 92                         dti:20.3-21.7      0.183321  4.224819e-03
# 93                         dti:21.7-22.4      0.157737  2.040707e-02
# 94                           dti:22.4-35      0.114173  6.040255e-02
# 95        mths_since_last_delinq:Missing      0.023618  6.906978e-01
# 96           mths_since_last_delinq:4-30      0.104830  5.614716e-02
# 97          mths_since_last_delinq:31-56      0.108441  7.315686e-02
# 98           mths_since_last_delinq:>=57      0.064925  2.922226e-01
# 99        mths_since_last_record:Missing     -0.393266  1.601293e-05
# 100          mths_since_last_record:3-20     -0.282077  3.091466e-02
# 101         mths_since_last_record:21-31     -0.352464  3.451258e-03
# 102         mths_since_last_record:32-80     -0.199276  3.546583e-02
# 103         mths_since_last_record:81-86     -0.381494  4.780921e-05
# 104          mths_since_last_record:>=86     -0.464816  3.923195e-07

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 84 columns]

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_base/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept      1.349052
# 1                               grade:A      1.006417
# 2                               grade:B      0.777700
# 3                               grade:C      0.593437
# 4                               grade:D      0.432984
# 5                               grade:E      0.303718
# 6                               grade:F      0.137947
# 7                    home_ownership:OWN      0.095503
# 8               home_ownership:MORTGAGE      0.109580
# 9                      addr_state:NM_VA      0.031821
# 10                        addr_state:NY      0.050363
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059854
# 12                        addr_state:CA      0.059249
# 13               addr_state:UT_KY_AZ_NJ      0.068786
# 14            addr_state:AR_MI_PA_OH_MN      0.129904
# 15            addr_state:RI_MA_DE_SD_IN      0.090802
# 16                  addr_state:GA_WA_OR      0.184499
# 17                     addr_state:WI_MT      0.240526
# 18                        addr_state:TX      0.218233
# 19                     addr_state:IL_CT      0.256266
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.310442
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.507021
# 22     verification_status:Not Verified      0.100507
# 23  verification_status:Source Verified     -0.009418
# 24                  purpose:credit_card      0.296774
# 25           purpose:debt_consolidation      0.190585
# 26           purpose:oth__med__vacation      0.215204
# 27  purpose:major_purch__car__home_impr      0.257227
# 28                initial_list_status:w      0.053947
# 29                              term:36      0.081089
# 30                         emp_length:1     -0.025452
# 31                       emp_length:2-4      0.079145
# 32                       emp_length:5-6      0.046005
# 33                       emp_length:7-9      0.018341
# 34                        emp_length:10      0.083091
# 35               mths_since_issue_d:<38      0.889782
# 36             mths_since_issue_d:38-39      0.685842
# 37             mths_since_issue_d:40-41      0.576385
# 38             mths_since_issue_d:42-48      0.380364
# 39             mths_since_issue_d:49-52      0.229460
# 40             mths_since_issue_d:53-64     -0.016199
# 41             mths_since_issue_d:65-84     -0.264971
# 42                      int_rate:<9.548      0.982547
# 43                int_rate:9.548-12.025      0.649267
# 44                int_rate:12.025-15.74      0.400250
# 45                int_rate:15.74-20.281      0.175028
# 46  mths_since_earliest_cr_line:141-164      0.053245
# 47  mths_since_earliest_cr_line:165-247      0.031712
# 48  mths_since_earliest_cr_line:248-270      0.078844
# 49  mths_since_earliest_cr_line:271-352      0.122103
# 50     mths_since_earliest_cr_line:>352      0.127719
# 51                     inq_last_6mths:0     -1.075043
# 52                   inq_last_6mths:1-2     -1.221865
# 53                   inq_last_6mths:3-6     -1.354434
# 54                   acc_now_delinq:>=1      0.206956
# 55                   annual_inc:20K-30K     -0.083906
# 56                   annual_inc:30K-40K     -0.022444
# 57                   annual_inc:40K-50K      0.075080
# 58                   annual_inc:50K-60K      0.140125
# 59                   annual_inc:60K-70K      0.214117
# 60                   annual_inc:70K-80K      0.289751
# 61                   annual_inc:80K-90K      0.364349
# 62                  annual_inc:90K-100K      0.382988
# 63                 annual_inc:100K-120K      0.460223
# 64                 annual_inc:120K-140K      0.547083
# 65                     annual_inc:>140K      0.495304
# 66                            dti:<=1.4      0.326224
# 67                          dti:1.4-3.5      0.446664
# 68                          dti:3.5-7.7      0.462908
# 69                         dti:7.7-10.5      0.399589
# 70                        dti:10.5-16.1      0.320399
# 71                        dti:16.1-20.3      0.221556
# 72                        dti:20.3-21.7      0.204852
# 73                        dti:21.7-22.4      0.177214
# 74                          dti:22.4-35      0.130736
# 75       mths_since_last_delinq:Missing      0.067606
# 76          mths_since_last_delinq:4-30      0.095993
# 77         mths_since_last_delinq:31-56      0.141686
# 78          mths_since_last_delinq:>=57      0.100087
# 79       mths_since_last_record:Missing     -0.460851
# 80          mths_since_last_record:3-20     -0.327332
# 81         mths_since_last_record:21-31     -0.438906
# 82         mths_since_last_record:32-80     -0.275925
# 83         mths_since_last_record:81-86     -0.462026
# 84          mths_since_last_record:>=86     -0.534138

# %%
p_values = reg2.p_values
p_values = np.append(np.nan, np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept      1.349052            NaN
# 1                               grade:A      1.006417   8.152078e-28
# 2                               grade:B      0.777700   5.420317e-36
# 3                               grade:C      0.593437   7.641820e-25
# 4                               grade:D      0.432984   2.703863e-15
# 5                               grade:E      0.303718   4.146378e-10
# 6                               grade:F      0.137947   6.358848e-03
# 7                    home_ownership:OWN      0.095503   2.432007e-06
# 8               home_ownership:MORTGAGE      0.109580   6.960892e-18
# 9                      addr_state:NM_VA      0.031821   3.230928e-01
# 10                        addr_state:NY      0.050363   3.885122e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059854   1.027459e-02
# 12                        addr_state:CA      0.059249   5.497615e-03
# 13               addr_state:UT_KY_AZ_NJ      0.068786   6.058065e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.129904   1.031393e-08
# 15            addr_state:RI_MA_DE_SD_IN      0.090802   2.475860e-03
# 16                  addr_state:GA_WA_OR      0.184499   6.532333e-12
# 17                     addr_state:WI_MT      0.240526   5.457299e-07
# 18                        addr_state:TX      0.218233   6.939297e-17
# 19                     addr_state:IL_CT      0.256266   3.049653e-18
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.310442   1.265320e-23
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.507021   2.173250e-21
# 22     verification_status:Not Verified      0.100507   7.299872e-12
# 23  verification_status:Source Verified     -0.009418   4.845272e-01
# 24                  purpose:credit_card      0.296774   6.243821e-25
# 25           purpose:debt_consolidation      0.190585   6.790796e-13
# 26           purpose:oth__med__vacation      0.215204   1.141695e-11
# 27  purpose:major_purch__car__home_impr      0.257227   6.045779e-16
# 28                initial_list_status:w      0.053947   3.564644e-05
# 29                              term:36      0.081089   8.379697e-09
# 30                         emp_length:1     -0.025452   3.049907e-01
# 31                       emp_length:2-4      0.079145   3.387764e-04
# 32                       emp_length:5-6      0.046005   5.879158e-02
# 33                       emp_length:7-9      0.018341   4.424937e-01
# 34                        emp_length:10      0.083091   1.582006e-04
# 35               mths_since_issue_d:<38      0.889782  5.855930e-120
# 36             mths_since_issue_d:38-39      0.685842   2.472543e-89
# 37             mths_since_issue_d:40-41      0.576385   7.171870e-67
# 38             mths_since_issue_d:42-48      0.380364   1.321185e-37
# 39             mths_since_issue_d:49-52      0.229460   4.369083e-13
# 40             mths_since_issue_d:53-64     -0.016199   5.876689e-01
# 41             mths_since_issue_d:65-84     -0.264971   1.006965e-18
# 42                      int_rate:<9.548      0.982547   3.818574e-37
# 43                int_rate:9.548-12.025      0.649267   1.213074e-46
# 44                int_rate:12.025-15.74      0.400250   1.098424e-26
# 45                int_rate:15.74-20.281      0.175028   3.439794e-09
# 46  mths_since_earliest_cr_line:141-164      0.053245   3.328376e-02
# 47  mths_since_earliest_cr_line:165-247      0.031712   1.162735e-01
# 48  mths_since_earliest_cr_line:248-270      0.078844   2.837732e-03
# 49  mths_since_earliest_cr_line:271-352      0.122103   2.229936e-07
# 50     mths_since_earliest_cr_line:>352      0.127719   1.711847e-06
# 51                     inq_last_6mths:0     -1.075043   6.765879e-21
# 52                   inq_last_6mths:1-2     -1.221865   1.554758e-26
# 53                   inq_last_6mths:3-6     -1.354434   5.456209e-32
# 54                   acc_now_delinq:>=1      0.206956   5.492452e-02
# 55                   annual_inc:20K-30K     -0.083906   5.208969e-02
# 56                   annual_inc:30K-40K     -0.022444   5.887213e-01
# 57                   annual_inc:40K-50K      0.075080   7.010751e-02
# 58                   annual_inc:50K-60K      0.140125   8.359676e-04
# 59                   annual_inc:60K-70K      0.214117   5.873931e-07
# 60                   annual_inc:70K-80K      0.289751   3.329874e-11
# 61                   annual_inc:80K-90K      0.364349   1.064774e-15
# 62                  annual_inc:90K-100K      0.382988   3.627489e-16
# 63                 annual_inc:100K-120K      0.460223   5.198510e-23
# 64                 annual_inc:120K-140K      0.547083   3.332944e-25
# 65                     annual_inc:>140K      0.495304   2.152024e-24
# 66                            dti:<=1.4      0.326224   1.567398e-04
# 67                          dti:1.4-3.5      0.446664   5.178497e-10
# 68                          dti:3.5-7.7      0.462908   7.638034e-14
# 69                         dti:7.7-10.5      0.399589   7.939900e-11
# 70                        dti:10.5-16.1      0.320399   7.001750e-08
# 71                        dti:16.1-20.3      0.221556   1.963165e-04
# 72                        dti:20.3-21.7      0.204852   9.771079e-04
# 73                        dti:21.7-22.4      0.177214   7.426696e-03
# 74                          dti:22.4-35      0.130736   2.618780e-02
# 75       mths_since_last_delinq:Missing      0.067606   2.101715e-01
# 76          mths_since_last_delinq:4-30      0.095993   7.846627e-02
# 77         mths_since_last_delinq:31-56      0.141686   1.028641e-02
# 78          mths_since_last_delinq:>=57      0.100087   7.631025e-02
# 79       mths_since_last_record:Missing     -0.460851   1.332034e-07
# 80          mths_since_last_record:3-20     -0.327332   1.009750e-02
# 81         mths_since_last_record:21-31     -0.438906   1.718213e-04
# 82         mths_since_last_record:32-80     -0.275925   2.421329e-03
# 83         mths_since_last_record:81-86     -0.462026   3.809468e-07
# 84          mths_since_last_record:>=86     -0.534138   1.289779e-09

# %%
import pickle

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))

# %% [markdown]
# # PD Model Test

# %%
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'mths_since_earliest_cr_line:141-164',
'mths_since_earliest_cr_line:165-247',
'mths_since_earliest_cr_line:248-270',
'mths_since_earliest_cr_line:271-352',
'mths_since_earliest_cr_line:>352',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>=86']]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'mths_since_earliest_cr_line:<140',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_train_with_ref_cat.drop(ref_categories,axis=1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>=86
# 427211                            0
# 206088                            0
# 136020                            0
# 412305                            0
# 36159                             0
#
# [5 rows x 84 columns]

# %%
y_hat_test = reg2.model.predict(inputs_test)

# %%
y_hat_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)

# %%
y_hat_test_proba
# Out:
# array([[0.03049041, 0.96950959],
#        [0.09185341, 0.90814659],
#        [0.03781568, 0.96218432],
#        ...,
#        [0.07736748, 0.92263252],
#        [0.08497743, 0.91502257],
#        [0.0924417 , 0.9075583 ]])

# %%
y_hat_test_proba[: ][: , 1]
# Out:
# array([0.96950959, 0.90814659, 0.96218432, ..., 0.92263252, 0.91502257,
#        0.9075583 ])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]

# %%
y_hat_test_proba
# Out:
# array([0.96950959, 0.90814659, 0.96218432, ..., 0.92263252, 0.91502257,
#        0.9075583 ])

# %%
loan_data_targets_test_temp = loan_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)

# %%
df_actual_predicted_probs.shape
# Out:
# (373028, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_test.index

# %%
df_actual_predicted_probs.head()
# Out:
#        loan_data_targets_test  y_hat_test_proba
# 427211               good_bad          0.969510
# 206088                      1          0.908147
# 136020                      1          0.962184
# 412305                      1          0.804825
# 36159                       1          0.827639

# %% [markdown]
# # Accuracy and Area uder the Curve

# %%
tr = 0.9
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted'])
# Out:
# Predicted      0      1
# Actual
# 0           4557   5485
# 1          37817  45398
# good_bad       0      1

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.012216  0.014704
# 1          0.101378  0.121701
# good_bad   0.000000  0.000003

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'],
           rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# Out:
# 0.1339175611482248

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
df_actual_predicted_probs['loan_data_targets_test'] = pd.to_numeric(df_actual_predicted_probs['loan_data_targets_test'], errors='coerce')
df_actual_predicted_probs = df_actual_predicted_probs.dropna(subset=['loan_data_targets_test'])

# %%
print(df_actual_predicted_probs['loan_data_targets_test'].dtype)
print(df_actual_predicted_probs['y_hat_test_proba'].dtype)
# Out:
# float64
# float64

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'],df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99990042, 1.        ,
#         1.        ]),
#  array([0.00000000e+00, 1.20170642e-05, 2.40341285e-05, ...,
#         9.99795710e-01, 9.99795710e-01, 1.00000000e+00]),
#  array([1.99250398, 0.99250398, 0.99196211, ..., 0.56867446, 0.56739798,
#         0.45907647]))

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99990042, 1.        ,
#         1.        ]),
#  array([0.00000000e+00, 1.20170642e-05, 2.40341285e-05, ...,
#         9.99795710e-01, 9.99795710e-01, 1.00000000e+00]),
#  array([1.99250398, 0.99250398, 0.99196211, ..., 0.56867446, 0.56739798,
#         0.45907647]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'],
                                 df_actual_predicted_probs['y_hat_test_proba'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
AUROC
# Out:
# 0.4984543293460382
